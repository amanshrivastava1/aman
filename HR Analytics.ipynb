# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dfe = pd.read_csv('C:/Users/hp/Desktop/Python/dataset/CAPSTONE/New folder/hr/employee_survey_data.csv')

# %% [markdown]
# ## Data profiing

# %%
dfe.shape
# Out:
# (4410, 4)

# %%
dfe.isnull().sum()
# Out:
# EmployeeID                  0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
df = pd.read_csv('C:/Users/hp/Desktop/Python/dataset/CAPSTONE/New folder/hr/general_data.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dfe.columns
# Out:
# Index(['EmployeeID', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance'],
#       dtype='object')

# %%
df = pd.merge(df, dfe,on='EmployeeID')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'],
#       dtype='object')

# %%
df.shape
# Out:
# (4410, 27)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4300, 27)

# %%
df.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4300.000000       4300.000000  4300.000000         4300.0  4300.000000
# mean     36.926977          9.197907     2.913256            1.0  2211.695116
# std       9.146517          8.097059     1.024774            0.0  1272.117692
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1110.750000
# 50%      36.000000          7.000000     3.000000            1.0  2215.500000
# 75%      43.000000         14.000000     4.000000            1.0  3314.250000
# max      60.000000         29.000000     5.000000            1.0  4409.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4300.000000    4300.000000         4300.000000        4300.000000
# mean      2.066977   65059.844186            2.690000          15.210698
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4300 entries, 0 to 4408
# Data columns (total 27 columns):
# Age                        4300 non-null int64
# Attrition                  4300 non-null object
# BusinessTravel             4300 non-null object
# Department                 4300 non-null object
# DistanceFromHome           4300 non-null int64
# Education                  4300 non-null int64
# EducationField             4300 non-null object
# EmployeeCount              4300 non-null int64
# EmployeeID                 4300 non-null int64
# Gender                     4300 non-null object
# JobLevel                   4300 non-null int64
# JobRole                    4300 non-null object
# MaritalStatus              4300 non-null object
# MonthlyIncome              4300 non-null int64
# NumCompaniesWorked         4300 non-null float64
# Over18                     4300 non-null object
# PercentSalaryHike          4300 non-null int64
# ...

# %%
df.hist(figsize=(15,14))
plt.show()

# %%
sns.countplot(df['Attrition'])

# %%
plt.subplots(figsize=(15,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
# here we can see that attrition is not much correlated with any of the variable and considering all of them

# %%
df['Attrition'] = df['Attrition'].map({'Yes':1, 'No':0})

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  StandardHours StockOptionLevel TotalWorkingYears  \
# 0  Female  ...              8                0               1.0
# ...

# %% [markdown]
# ### Checking the attrition between male and female

# %%
df[df['Attrition']==1]['Gender'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### males tend to leave a company may be due to better income options

# %% [markdown]
# -------------------------------

# %% [markdown]
# #### Lets checking if age palys key role in attrition

# %%
sns.barplot(df['Attrition'],df['Age'])

# %% [markdown]
# #### As the age is below 35 employee might be more prone to leave a company

# %% [markdown]
# -------------------

# %% [markdown]
# #### We will check the max Attrition from which department

# %%
df[df['Attrition']==1]['Department'].value_counts().plot(kind='bar',color=['r','b','g'],figsize=(10,4))
plt.show()

# %% [markdown]
# #### here we can see the significant attrition from the R&D department

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'EnvironmentSatisfaction', 'JobSatisfaction', 'WorkLifeBalance'],
#       dtype='object')

# %% [markdown]
# #### Finding the connection between marital status and atttrition

# %%
df[df['Attrition']==1]['MaritalStatus'].value_counts().plot(kind='bar', color=['blue','pink','orange'],figsize=(10,4))
plt.show()

# %% [markdown]
# #### Single's tend to leave a company more as compared to maried and Divorced. Hence Married are more stable resource for a company

# %% [markdown]
# ---------------------

# %% [markdown]
# ### Attrition and MaritalStatus

# %%
df[df['Attrition']==0]['MaritalStatus'].value_counts().plot(kind='bar', color=['blue','pink','orange'],figsize=(10,4))
plt.show()

# %%
sns.barplot(df['Attrition'],df['TotalWorkingYears'])
plt.show()

# %% [markdown]
# ##### As expected chances of lower experience resource tend to leave the company is more.

# %% [markdown]
# --------------------------

# %% [markdown]
# #### Checking relation between job satisfaction and the attrition rate

# %%
df[df['Attrition']==1]['JobSatisfaction'].sort_values().value_counts().plot(kind='bar', color=['blue','pink','orange','yellow'],figsize=(10,4))
plt.show()

# %% [markdown]
# 1 - bad,
# 2 - average,
# 3 - better,
# 4 - best
# #### Here it is very interesting to see that attrition of resource who have better rating is more then bad and average. Resource having average attrition is the least among all.

# %% [markdown]
# ------------------

# %% [markdown]
# #### income plays important role in attrition of an employ.

# %%
sns.boxplot(df['Attrition'],df['MonthlyIncome'])
plt.show()

# %%
# most of the attrition happen between the income of 20000 to 70000. There are certain attrition having the higher package

# %% [markdown]
# -----------

# %% [markdown]
# #### distance of home from office is also important factor. Lets check how it impact the attrition rate

# %%
sns.boxplot(df['Attrition'],df['DistanceFromHome'])

# %% [markdown]
# ##### Ditance do not play much important factor in the attrition of the resource as we cannot see any such significant difference here although the attrition rate is slight high for higher distance but we were expecting significant difference between attrition and non attrition in terms of distance rom home

# %% [markdown]
# -----------

# %%
sns.boxplot(df['Attrition'],df['TotalWorkingYears'])

# %% [markdown]
# ##### As we have seen the attrition is more with age limit lesser then 35 age employee so supporting the same insight, here we have got the attrition rate with resource having lesser experience

# %% [markdown]
# ----------------

# %% [markdown]
# #### Checking the attriton among the employee who travel frequently and the one who do not.

# %%
df[df['Attrition'] == 1]['BusinessTravel'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# #### interesting to see tha resource who travel rarely is more likely to leave the company then frequent traveller and non traveller

# %% [markdown]
# ---------------

# %%
fig,axis = plt.subplots(1,4,figsize=(15,6))
df[df['Attrition'] == 1]['WorkLifeBalance'].value_counts().plot(kind='bar',ax=axis[0])
df[df['Attrition'] == 1]['JobRole'].value_counts().plot(kind='bar',ax=axis[1])
df[df['Attrition'] == 1]['Education'].value_counts().plot(kind='bar',ax=axis[2])
df[df['Attrition'] == 1]['EnvironmentSatisfaction'].value_counts().plot(kind='bar',ax=axis[3])

# %% [markdown]
# Here we checking worklife balance, Jobrole and Education level of the employee effects the attrition rate
#
# A) Worklife balance :
#
# 1 'Bad'- 1
#
# 2 'Good' - 2
#
# 3 'Better' - 3
#
# 4 'Best'- 4
#
# Very interesting outcome we see here. The attrition rate of employee having better worklife balance is most and employe having bad worklife balance is the least.
#
# B)Jobrole:
#
# Top jobrole from where the attrition rate is more is Sales executive, Research Scietist, Laboatory technician, hr have the least.
# These might me due to hectic work or better financial options in this field.
#
# C) Education:
#
# 1-'Below College'
#
# 2-'College'
#
# 3-'Bachelor'
#
# 4-'Master'
#
# 5-'Doctor'
#
# The employee with Bechelor degree tend to have hgher chanc of attition, followed by masters and then college passout.
# They might be getting lucrative salary option outside the company due to their degree and experience in particular field.
#
# D) Environment Satisfaction :
#
# 1 'Bad'- 1
#
# 2 'Good' - 2
#
# 3 'Better' - 3
#
# 4 'Best'- 4
#
# As expected employee with bad Env. Sat. is mor likely to churn hence good environmet is necessary for employee to work.

# %% [markdown]
# ------------

# %%
sns.violinplot(df['Attrition'],df['PercentSalaryHike'])
plt.show()

# %% [markdown]
# Salary hike might result in retaining an employee back as high percntage hike employee tend to churn as well.

# %% [markdown]
# ---------

# %%
df[df['Attrition'] == 1]['NumCompaniesWorked'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ------------------

# %% [markdown]
# So we have done a lot of EDA here with different variable and attrition .
# Let us summarize it :
#
# I would suggest the company to maintain good positive working environment plus provide proper amount of time to employee to balance work.
#
# Emloyee with lesser income are more likely to churn. So lookng at the performance of the employee salary could be hiked appropriately.
#
# Company should encourage business trips for employee on rotational period as employee who travels are more lkely to churn .
#
# Company is doing job in keeping the married resource with them. They need find measures to restrict the single resource from leaving the company.
#
# Company need to check why there se high number of attrition in the R&D department and find the root cause.Like whether its salary, working environmnet, work pressure, etc
#
# Taking resource who have worked in more than 1 comapnies tend to decrese the attrition rate exponentially

# %% [markdown]
# ## Data Preprocesing

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# 2                17          4          Other              1           3
# 3                 2          5  Life Sciences              1           4
# 4                10          1        Medical              1           5
#
#    Gender  ...  StandardHours StockOptionLevel TotalWorkingYears  \
# 0  Female  ...              8                0               1.0
# ...

# %% [markdown]
# #### Using label encoder for less then 2 class and using one hot encoding for remaining more then 2 class

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df['Over18'] = le.fit_transform(df['Over18'])

# %%
df['Attrition'] = df['Attrition'].astype('int64')

# %% [markdown]
# --------

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
cols = df.columns

# %%
df.shape
# Out:
# (4300, 41)

# %%
df.head()
# Out:
#    Age  Attrition  DistanceFromHome  Education  EmployeeCount  EmployeeID  \
# 0   51          0                 6          2              1           1
# 1   31          1                10          1              1           2
# 2   32          0                17          4              1           3
# 3   38          0                 2          5              1           4
# 4   32          0                10          1              1           5
#
#    Gender  JobLevel  MonthlyIncome  NumCompaniesWorked  ...  \
# 0       0         1         131160                 1.0  ...
# 1       0         1          41890                 0.0  ...
# 2       1         4         193280                 1.0  ...
# 3       1         3          83210                 3.0  ...
# 4       1         1          23420                 4.0  ...
#
#    JobRole_Human Resources  JobRole_Laboratory Technician  JobRole_Manager  \
# 0                        0                              0                0
# ...

# %%
# dropping certain columns which will not help in providing inference

# %%
df.drop(['EmployeeCount','StandardHours','Over18'],axis=1,inplace=True)

# %%
plt.subplots(figsize=(25,20))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
#Splitting the model

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'DistanceFromHome', 'Education', 'EmployeeID',
#        'Gender', 'JobLevel', 'MonthlyIncome', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'EnvironmentSatisfaction', 'JobSatisfaction',
#        'WorkLifeBalance', 'BusinessTravel_Travel_Frequently',
#        'BusinessTravel_Travel_Rarely', 'Department_Research & Development',
#        'Department_Sales', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
#        'JobRole_Research Director', 'JobRole_Research Scientist',
#        'JobRole_Sales Executive', 'JobRole_Sales Representative',
# ...

# %%
df.shape
# Out:
# (4300, 38)

# %%
X = df.drop(['Attrition','EmployeeID'],axis=1)

# %%
cols = X.columns

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
X = ss.fit_transform(X)

# %%
X = pd.DataFrame(X, columns=cols)

# %%
X.head()
# Out:
#         Age  DistanceFromHome  Education    Gender  JobLevel  MonthlyIncome  \
# 0  1.538800         -0.394993  -0.891282 -1.219421 -0.964277       1.405193
# 1 -0.648079          0.099071  -1.867220 -1.219421 -0.964277      -0.492557
# 2 -0.538735          0.963683   1.060595  0.820062  1.746964       2.725773
# 3  0.117329         -0.889057   2.036534  0.820062  0.843217       0.385846
# 4 -0.538735          0.099071  -1.867220  0.820062 -0.964277      -0.885202
#
#    NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0           -0.677226          -1.149725         -0.931939          -1.320442
# 1           -1.077952           2.126858          0.239797          -0.678523
# 2           -0.677226          -0.057531          2.583269          -0.806907
# 3            0.124225          -1.149725          2.583269           0.220163
# 4            0.524950          -0.876677          1.411533          -0.293372
#
# ...

# %%
y = df['Attrition']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7,test_size=0.3,random_state=100)

# %%
X_train.shape
# Out:
# (3010, 36)

# %%
y_train.shape
# Out:
# (3010,)

# %%
import statsmodels.api as sm
from sklearn.linear_model import LogisticRegression

# %%
#logreg = LogisticRegression()
#logreg.fit(X_train, y_train)

# %%
#y_pred = logreg.predict(X_test)

# %%
#logreg.score(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
from sklearn import svm, tree, linear_model, neighbors
from sklearn import naive_bayes, ensemble, discriminant_analysis, gaussian_process
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
#!pip install xgboost

# %%
from xgboost import XGBClassifier
from sklearn import model_selection

# %%
from sklearn.metrics import confusion_matrix, classification_report, precision_recall_curve
from sklearn.metrics import auc, roc_auc_score, roc_curve, recall_score, log_loss
from sklearn.metrics import f1_score, accuracy_score, make_scorer
from sklearn.metrics import average_precision_score

# %% [markdown]
# #### First we build the baseline model before going for sophisticated model with hyper parameter tunning

# %%
# selection of algorithms to consider and set performance measure
models = []

models.append(('Logistic Regression', LogisticRegression(solver='liblinear', random_state=7,
                                                         class_weight='balanced')))
models.append(('Random Forest', RandomForestClassifier(
    n_estimators=100, random_state=7)))
models.append(('SVM', SVC(gamma='auto', random_state=7)))
models.append(('KNN', KNeighborsClassifier()))
models.append(('Decision Tree Classifier',
               DecisionTreeClassifier(random_state=7)))
models.append(('Gaussian NB', GaussianNB()))

# %%
acc_results = []
auc_results = []
names = []
# set table to table to populate with performance results
col = ['Algorithm', 'ROC AUC Mean', 'ROC AUC STD', 
       'Accuracy Mean', 'Accuracy STD']
df_results = pd.DataFrame(columns=col)
i = 0
# evaluate each model using cross-validation
for name, model in models:
    kfold = model_selection.KFold(
        n_splits=10, random_state=7)  # 10-fold cross-validation

    cv_acc_results = model_selection.cross_val_score(  # accuracy scoring
        model, X_train, y_train, cv=kfold, scoring='accuracy')

    cv_auc_results = model_selection.cross_val_score(  # roc_auc scoring
        model, X_train, y_train, cv=kfold, scoring='roc_auc')

    acc_results.append(cv_acc_results)
    auc_results.append(cv_auc_results)
    names.append(name)
    df_results.loc[i] = [name,
                         round(cv_auc_results.mean()*100, 2),
                         round(cv_auc_results.std()*100, 2),
                         round(cv_acc_results.mean()*100, 2),
                         round(cv_acc_results.std()*100, 2)
                         ]
    i += 1
df_results.sort_values(by=['ROC AUC Mean'], ascending=False)
# Out:
#                   Algorithm  ROC AUC Mean  ROC AUC STD  Accuracy Mean  \
# 1             Random Forest         98.51         0.81          97.44
# 4  Decision Tree Classifier         93.43         2.28          96.38
# 2                       SVM         91.65         2.88          89.14
# 3                       KNN         84.15         1.24          82.89
# 0       Logistic Regression         76.29         3.59          68.87
# 5               Gaussian NB         70.02         2.97          76.88
#
#    Accuracy STD
# 1          0.96
# 4          0.75
# 2          2.04
# 3          1.47
# 0          2.62
# 5          2.01

# %%
fig = plt.figure(figsize=(15, 7))
fig.suptitle('Algorithm Accuracy Comparison')
ax = fig.add_subplot(111)
plt.boxplot(acc_results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# ### Area under ROC Curve (or AUC for short) is a performance metric for binary classification problems.
# The AUC represents a model’s ability to discriminate between positive and negative classes. An area of 1.0 represents a model that made all predictions perfectly. An area of 0.5 represents a model as good as random.

# %%
fig = plt.figure(figsize=(15, 7))
fig.suptitle('Algorithm ROC AUC Comparison')
ax = fig.add_subplot(111)
plt.boxplot(auc_results)
ax.set_xticklabels(names)
plt.show()

# %% [markdown]
# ####  Based on our ROC AUC comparison analysis, Random Forest shows the highest mean AUC scores. We will shortlist this  algorithm for our further analysis.

# %% [markdown]
# ### Random Forest Classifier
# #### Hyper - Parameter tunning using Grid search.

# %%
rf_classifier = RandomForestClassifier(class_weight = "balanced",
                                       random_state=7)
param_grid = {'n_estimators': [50, 75, 100],
              'min_samples_split':[2,4],
              'min_samples_leaf': [1, 2],
              'max_depth': [ 15, 20, 25]}

grid_obj = GridSearchCV(rf_classifier,
                        iid=True,
                        return_train_score=True,
                        param_grid=param_grid,
                        scoring='roc_auc',
                        cv=5)

grid_fit = grid_obj.fit(X_train, y_train)
rf_opt = grid_fit.best_estimator_

print('='*20)
print("best params: " + str(grid_obj.best_estimator_))
print("best params: " + str(grid_obj.best_params_))
print('best score:', grid_obj.best_score_)
print('='*20)
# Out:
# ...
# best params: RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=25, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=7, verbose=0, warm_start=False)
# best params: {'max_depth': 25, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# best score: 0.9746079780351691
# ...

# %% [markdown]
# ### Random Forest allows us to know which features are of the most importance in predicting the target feature ("attrition" in this project). Below, we plot features by their importance.

# %%
importances = rf_opt.feature_importances_
indices = np.argsort(importances)[::-1] # Sort feature importances in descending order
names = [X_train.columns[i] for i in indices] # Rearrange feature names so they match the sorted feature importances
plt.figure(figsize=(15, 7)) # Create plot
plt.title("Feature Importance") # Create plot title
plt.bar(range(X_train.shape[1]), importances[indices]) # Add bars
plt.xticks(range(X_train.shape[1]), names, rotation=90) # Add feature names as x-axis labels
plt.show() # Show plot

# %% [markdown]
# #### Random forest helped us identify top most performing features

# %%
importances = rf_opt.feature_importances_
df_param_coeff = pd.DataFrame(columns=['Feature', 'Coefficient'])
for i in range(36):
    feat = X_train.columns[i]
    coeff = importances[i]
    df_param_coeff.loc[i] = (feat, coeff)
df_param_coeff.sort_values(by='Coefficient', ascending=False, inplace=True)
df_param_coeff = df_param_coeff.reset_index(drop=True)
df_param_coeff.head(10)
# Out:
#                    Feature  Coefficient
# 0                      Age     0.085496
# 1        TotalWorkingYears     0.082299
# 2            MonthlyIncome     0.081664
# 3           YearsAtCompany     0.069026
# 4         DistanceFromHome     0.058843
# 5     YearsWithCurrManager     0.056992
# 6        PercentSalaryHike     0.054423
# 7       NumCompaniesWorked     0.045509
# 8  EnvironmentSatisfaction     0.041599
# 9    TrainingTimesLastYear     0.037713

# %% [markdown]
# ## Confusion matrix

# %%
cnf_matrix = confusion_matrix(y_test, rf_opt.predict(X_test))
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print('Accuracy of RandomForest Regression Classifier on test set: {:.2f}'.format(rf_opt.score(X_test, y_test)*100))
# Out:
# Accuracy of RandomForest Regression Classifier on test set: 98.68

# %% [markdown]
# #### The Confusion matrix is telling us that we have 1093+183 correct predictions and 14+0 incorrect predictions. In other words, an accuracy of 98.91%.

# %%
# Classification report for the optimised RF Regression
rf_opt.fit(X_train, y_train)
print(classification_report(y_test, rf_opt.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1093
#            1       0.98      0.93      0.96       197
#
#     accuracy                           0.99      1290
#    macro avg       0.99      0.96      0.97      1290
# weighted avg       0.99      0.99      0.99      1290

# %%
rf_opt.fit(X_train, y_train) # fit optimised model to the training data
probs = rf_opt.predict_proba(X_test) # predict probabilities
probs = probs[:, 1] # we will only keep probabilities associated with the employee leaving
rf_opt_roc_auc = roc_auc_score(y_test, probs) # calculate AUC score using test dataset
print('AUC score: %.3f' % rf_opt_roc_auc)
# Out:
# AUC score: 0.995

# %%
##### Here we can se tha our model is giving us very good predition based on the data given

# %% [markdown]
# #### AUC - ROC curve is a performance measurement for classification problem at various thresholds settings. ROC is a probability curve and AUC represents degree or measure of separability. It tells how much model is capable of distinguishing between classes.
# #### The orange line represents the ROC curve of a purely random classifier; a good classifier stays as far away from that line as possible (toward the top-left corner).

# %%
# Create ROC Graph
from sklearn.metrics import roc_curve

rf_fpr, rf_tpr, rf_thresholds = roc_curve(y_test, rf_opt.predict_proba(X_test)[:,1])
plt.figure(figsize=(14, 6))

#
# Plot Random Forest ROC
plt.plot(rf_fpr, rf_tpr, label='Random Forest (area = %0.2f)' % rf_opt_roc_auc)
# Plot Base Rate ROC
plt.plot([0,1], [0,1],label='Base Rate' 'k--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Graph')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Monthly Income:
# #### people on higher wages are less likely to leave the company. Hence, efforts should be made to gather information on industry benchmarks in the current local market to determine if the company is providing competitive wages.
#
# ### Age:
# #### Employees in relatively young age bracket 25-35 are more likely to leave. Hence, efforts should be made to clearly articulate the long-term vision of the company and young employees fit in that vision, as well as provide incentives in the form of clear paths to promotion for instance.
#
# ### DistanceFromHome:
# #### Employees who live further from home are more likely to leave the company. Hence, efforts should be made to provide support in the form of company transportation for clusters of employees leaving the same area, or in the form of Transportation Allowance. Initial screening of employees based on their home location is probably not recommended as it would be regarded as a form of discrimination as long as employees make it to work on time every day.
#
# ### TotalWorkingYears:
# #### The more experienced employees are less likely to leave. Employees who have between 5-8 years of experience should be identified as potentially having a higher-risk of leaving
#
# ### YearsAtCompany:
# #### Loyal companies are less likely to leave. Employees who hit their two-year anniversary should be identified as potentially having a higher-risk of leaving.
#
#
# ##### A strategic "Retention Plan" should be drawn for each Risk Category group. In addition to the suggested steps for each feature listed above, face-to-face meetings between a HR representative and employees can be initiated for medium- and high-risk employees to discuss work conditions. Also, a meeting with those employee's Line Manager would allow to discuss the work environment within the team and whether steps can be taken to improve it.
